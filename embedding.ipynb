# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
# Test Sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
# Define Vocab size
voc_size=10000

# %%
# One hot representation for every word
one_hot_rep=[one_hot(words,voc_size)for words in sent ]
one_hot_rep
# Out:
# [[7743, 3516, 4871, 5613],
#  [7743, 3516, 4871, 388],
#  [7743, 5649, 4871, 775],
#  [52, 7939, 7901, 1990, 9690],
#  [52, 7939, 7901, 1990, 1254],
#  [6901, 7743, 6985, 4871, 502],
#  [8707, 7572, 4821, 1990]]

# %%
# Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
# Using pad_sequence to make all sentences of same length
sent_length=8
embedded_docs=pad_sequences(one_hot_rep, padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 7743 3516 4871 5613]
#  [   0    0    0    0 7743 3516 4871  388]
#  [   0    0    0    0 7743 5649 4871  775]
#  [   0    0    0   52 7939 7901 1990 9690]
#  [   0    0    0   52 7939 7901 1990 1254]
#  [   0    0    0 6901 7743 6985 4871  502]
#  [   0    0    0    0 8707 7572 4821 1990]]

# %%
# Feature Representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.02229739, -0.00919948, -0.02470627,  0.02358413,
#          -0.00893492, -0.01986744,  0.03313366,  0.04789546,
#          -0.00740186, -0.04471467],
#         [ 0.03746476, -0.0164771 , -0.00917566, -0.0042284 ,
#           0.02832044, -0.02570903, -0.02889969,  0.02562897,
#           0.00234978, -0.0305512 ],
#         [-0.0290313 , -0.02446985,  0.02006784, -0.02533392,
#          -0.03614811,  0.04655189,  0.03211189, -0.04187857,
#          -0.04629998,  0.00528369],
#         [ 0.00017943,  0.02304449, -0.03214244, -0.02037058,
#           0.04000897, -0.01186405,  0.03699178, -0.0393455 ,
#          -0.02618281, -0.04677603]],
#
#        [[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.02229739, -0.00919948, -0.02470627,  0.02358413,
#          -0.00893492, -0.01986744,  0.03313366,  0.04789546,
#          -0.00740186, -0.04471467],
#         [ 0.03746476, -0.0164771 , -0.00917566, -0.0042284 ,
#           0.02832044, -0.02570903, -0.02889969,  0.02562897,
#           0.00234978, -0.0305512 ],
#         [-0.0290313 , -0.02446985,  0.02006784, -0.02533392,
#          -0.03614811,  0.04655189,  0.03211189, -0.04187857,
#          -0.04629998,  0.00528369],
#         [ 0.0341169 , -0.00372869, -0.04194208,  0.00051744,
#          -0.00736697, -0.02459108,  0.01113557,  0.03485818,
#          -0.03894812,  0.01781497]],
#
#        [[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.02229739, -0.00919948, -0.02470627,  0.02358413,
#          -0.00893492, -0.01986744,  0.03313366,  0.04789546,
#          -0.00740186, -0.04471467],
#         [ 0.04859494, -0.01495426, -0.04936492,  0.04638446,
#          -0.01924914,  0.04233268,  0.01752902,  0.00172174,
#          -0.02916314,  0.00383762],
#         [-0.0290313 , -0.02446985,  0.02006784, -0.02533392,
#          -0.03614811,  0.04655189,  0.03211189, -0.04187857,
#          -0.04629998,  0.00528369],
#         [-0.02843384,  0.00016776,  0.01080621,  0.01016482,
#           0.02413953, -0.00095413,  0.03332743, -0.0233128 ,
#          -0.03388082,  0.00483798]],
#
#        [[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.00113349,  0.01997796,  0.00238272,  0.02554972,
#          -0.03189877, -0.02830297, -0.00087724,  0.03418947,
#          -0.03501513, -0.01572515],
#         [ 0.02517157, -0.03551996, -0.01983568, -0.03909844,
#          -0.02860653, -0.03688348,  0.0277814 ,  0.04864329,
#          -0.00015596, -0.01733533],
#         [-0.0168197 ,  0.04122204,  0.02512847,  0.04010326,
#           0.02350986, -0.02516859,  0.03699758,  0.04295691,
#          -0.02038446,  0.00792904],
#         [-0.00738324,  0.03318531, -0.01529248,  0.02857721,
#           0.02739688,  0.02620585,  0.01480665, -0.02703433,
#          -0.00832325, -0.03237493],
#         [ 0.0038505 , -0.00701219, -0.02050032, -0.03307029,
#          -0.04716805, -0.00165062,  0.03457112,  0.01338872,
#           0.03646867, -0.04954567]],
#
#        [[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.00113349,  0.01997796,  0.00238272,  0.02554972,
#          -0.03189877, -0.02830297, -0.00087724,  0.03418947,
#          -0.03501513, -0.01572515],
#         [ 0.02517157, -0.03551996, -0.01983568, -0.03909844,
#          -0.02860653, -0.03688348,  0.0277814 ,  0.04864329,
#          -0.00015596, -0.01733533],
#         [-0.0168197 ,  0.04122204,  0.02512847,  0.04010326,
#           0.02350986, -0.02516859,  0.03699758,  0.04295691,
#          -0.02038446,  0.00792904],
#         [-0.00738324,  0.03318531, -0.01529248,  0.02857721,
#           0.02739688,  0.02620585,  0.01480665, -0.02703433,
#          -0.00832325, -0.03237493],
#         [ 0.00087142, -0.02030505,  0.03774028,  0.01914432,
#          -0.01855116,  0.01508826, -0.01253126, -0.0439334 ,
#          -0.02130175, -0.02393762]],
#
#        [[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [-0.04653794,  0.02237857,  0.04880634, -0.04474362,
#          -0.04435978,  0.00680605,  0.04844875, -0.02220449,
#           0.04401583,  0.03902569],
#         [ 0.02229739, -0.00919948, -0.02470627,  0.02358413,
#          -0.00893492, -0.01986744,  0.03313366,  0.04789546,
#          -0.00740186, -0.04471467],
#         [-0.0144398 ,  0.04317378,  0.03577704, -0.01878862,
#           0.03875161, -0.00985809, -0.02626514, -0.03868803,
#          -0.01507007,  0.03492217],
#         [-0.0290313 , -0.02446985,  0.02006784, -0.02533392,
#          -0.03614811,  0.04655189,  0.03211189, -0.04187857,
#          -0.04629998,  0.00528369],
#         [-0.01903949, -0.00880265, -0.01273806,  0.04419276,
#           0.04253263, -0.0419121 , -0.00939261, -0.01225703,
#           0.03234922,  0.00281217]],
#
#        [[ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [ 0.0318065 ,  0.01684512, -0.04875542, -0.0171394 ,
#           0.0035492 ,  0.00679767,  0.03914714,  0.02623082,
#          -0.02302997, -0.04521028],
#         [-0.02341993, -0.01407154,  0.01714578, -0.03817094,
#           0.00162724, -0.00870798,  0.04720051, -0.02044532,
#          -0.03769363,  0.01279971],
#         [-0.04727099, -0.02354093, -0.02164646, -0.0262491 ,
#          -0.02614042,  0.02069673,  0.04165239,  0.03853307,
#          -0.00987958, -0.01146698],
#         [ 0.04018888, -0.03700999, -0.02179793,  0.03037372,
#          -0.01489265, -0.00951307,  0.04383166,  0.0223711 ,
#           0.01559026,  0.0025514 ],
#         [-0.00738324,  0.03318531, -0.01529248,  0.02857721,
#           0.02739688,  0.02620585,  0.01480665, -0.02703433,
#          -0.00832325, -0.03237493]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7743, 3516, 4871, 5613], dtype=int32)
